# %% [markdown]
# Display a scatter plot of the iris dataset, with the sepal length on the x-axis and the sepal width on the y-axis.
#
# Create a bar chart of the number of flowers in each species category (setosa, versicolor, and virginica).
#
# Display a scatter plot of the iris dataset, with the petal length on the x-axis and the petal width on the y-axis. Use different colors for each species.
#
# Create a box plot of the sepal length for each species.
#
# Create a histogram of the sepal width, with 10 bins.
#
# Display a scatter plot of the iris dataset, with the sepal length on the x-axis and the petal length on the y-axis. Use different colors for each species.
#
# Create a bar chart of the mean petal length for each species.
#
# Display a scatter plot of the iris dataset, with the petal length on the x-axis and the sepal width on the y-axis. Use different colors for each species.
#
# Create a box plot of the petal width for each species.
#
# Display a scatter plot of the iris dataset, with the sepal length on the x-axis and the petal width on the y-axis. Use different colors for each species.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
setosa = df[df['species'] == 'setosa']
versicolor = df[df['species'] == 'versicolor']
virginica = df[df['species'] == 'virginica']

# %%
plt.scatter(df['sepal_length'],df['sepal_width'])
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')
# Out:
# Text(0, 0.5, 'sepal_width')

# %%
plt.bar(df['species'], df['species'].count())
# Out:
# <BarContainer object of 150 artists>

# %%
plt.scatter(setosa['petal_length'], setosa['petal_width'], c='red')
plt.xlabel('petal_length')
plt.ylabel('petal_width')
# Out:
# Text(0, 0.5, 'petal_width')

# %%
plt.scatter(versicolor['petal_length'], versicolor['petal_width'], c='black')
plt.xlabel('petal_length')
plt.ylabel('petal_width')
# Out:
# Text(0, 0.5, 'petal_width')

# %%
plt.scatter(virginica['petal_length'], virginica['petal_width'], c='green')
plt.xlabel('petal_length')
plt.ylabel('petal_width')
# Out:
# Text(0, 0.5, 'petal_width')

# %%
plt.boxplot([setosa['sepal_length'], versicolor ['sepal_length'], virginica['sepal_length']])
plt.xticks([1, 2, 3], ['setosa', 'versicolor', 'virginica'])
plt.ylabel('Sepal Length')
# Out:
# Text(0, 0.5, 'Sepal Length')

# %%
plt.hist(df['sepal_width'], bins = 10)
plt.xlabel('Sepal Width')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.scatter(setosa['sepal_length'], setosa['petal_length'], c='blue')
plt.xlabel('sepal_length')
plt.ylabel('petal_length')
# Out:
# Text(0, 0.5, 'petal_length')

# %%
plt.scatter(versicolor['sepal_length'], versicolor['petal_length'], c='pink')
plt.xlabel('sepal_length')
plt.ylabel('petal_length')
# Out:
# Text(0, 0.5, 'petal_length')

# %%
plt.scatter(virginica['sepal_length'], virginica['petal_length'], c='gold')
plt.xlabel('sepal_length')
plt.ylabel('petal_length')
# Out:
# Text(0, 0.5, 'petal_length')

# %%
df.groupby('species')['petal_length'].mean()
plt.bar(df.groupby('species')['petal_length'].mean().index, df.groupby('species')['petal_length'].mean().values)
plt.xlabel('Species')
plt.ylabel('Mean Petal Length')
# Out:
# Text(0, 0.5, 'Mean Petal Length')

# %%
plt.scatter(setosa['petal_length'], setosa['sepal_width'], c='lightblue')
plt.xlabel('petal length')
plt.ylabel('sepal width')
# Out:
# Text(0, 0.5, 'sepal width')

# %%
plt.scatter(versicolor['petal_length'], versicolor['sepal_width'], c='purple')
plt.xlabel('petal length')
plt.ylabel('sepal width')
# Out:
# Text(0, 0.5, 'sepal width')

# %%
plt.scatter(virginica['petal_length'], virginica['sepal_width'], c='aquamarine')
plt.xlabel('petal length')
plt.ylabel('sepal width')
# Out:
# Text(0, 0.5, 'sepal width')

# %%
plt.boxplot([setosa['petal_width'], versicolor ['petal_width'], virginica['petal_width']])
plt.xticks([1, 2, 3], ['setosa', 'versicolor', 'virginica'])
plt.ylabel('Petal Width')
# Out:
# Text(0, 0.5, 'Petal Width')

# %%
plt.scatter(setosa['sepal_length'], setosa['petal_width'], c='grey')
plt.xlabel('sepal length')
plt.ylabel('petal width')
# Out:
# Text(0, 0.5, 'petal width')

# %%
plt.scatter(versicolor['sepal_length'], versicolor['petal_width'], c='white',edgecolors='black',)
plt.xlabel('sepal length')
plt.ylabel('petal width')
# Out:
# Text(0, 0.5, 'petal width')

# %%
plt.scatter(virginica['sepal_length'], virginica['petal_width'], c='silver')
plt.xlabel('sepal length')
plt.ylabel('petal width')
# Out:
# Text(0, 0.5, 'petal width')
